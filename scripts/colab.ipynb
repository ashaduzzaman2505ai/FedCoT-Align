# %%
# !git clone https://github.com/ashaduzzaman2505ai/FedCoT-Align.git
# %cd FedCoT-Align
# !ls
# Out:
# Cloning into 'FedCoT-Align'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 28 (delta 4), reused 24 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 9.27 KiB | 9.27 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/FedCoT-Align
# baselines   experiments  models		       requirements.txt
# configs     fed		 project_structure.py  scripts
# data	    __init__.py  pyproject.toml        training
# evaluation  LICENSE	 README.md	       utils

# %%
# !pip install poetry
# !poetry install
# Out:
# Creating virtualenv fedcot-align-f70KEcS9-py3.12 in /root/.cache/pypoetry/virtualenvs
# Updating dependencies
# Resolving dependencies... (18.1s)Resolving dependencies... (6.5s)
#
# Package operations: 104 installs, 0 updates, 0 removals
#
#   - Installing certifi (2026.1.4): Pending...
#   - Installing frozenlist (1.8.0): Pending...
#   - Installing h11 (0.16.0): Pending...
#   - Installing idna (3.11): Pending...
#   - Installing multidict (6.7.0): Pending...
#   - Installing propcache (0.4.1): Pending...
#   - Installing h11 (0.16.0): Pending...
#   - Installing idna (3.11): Pending...
#   - Installing multidict (6.7.0): Pending...
#   - Installing propcache (0.4.1): Pending...
#   - Installing frozenlist (1.8.0): Downloading... 0%
#   - Installing h11 (0.16.0): Pending...
#   - Installing idna (3.11): Pending...
#   - Installing multidict (6.7.0): Pending...
#   - Installing propcache (0.4.1): Pending...
#   - Installing h11 (0.16.0): Pending...
# ...
