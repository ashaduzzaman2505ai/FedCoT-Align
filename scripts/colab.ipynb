# %%
# !git clone https://github.com/ashaduzzaman2505ai/FedCoT-Align.git
# %cd FedCoT-Align
# !rm -rf FedCoT-Align
# !ls
# Out:
# Cloning into 'FedCoT-Align'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 77 (delta 10), reused 68 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (77/77), 190.07 KiB | 6.79 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/FedCoT-Align
# baselines   experiments  poetry.lock	       requirements.txt
# configs     fed		 project_structure.py  scripts
# data	    LICENSE	 pyproject.toml        training
# evaluation  models	 README.md	       utils

# %%
# !pip install poetry
# !poetry install
# Out:
# ...
# Installing dependencies from lock file
#
# No dependencies to install or update
#
# Installing the current project: fedcot-align (0.1.0)
# /content/FedCoT-Align/fedcot_align does not contain any element

# %%
# !pip install -r requirements.txt

# %%
# !python experiments/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/FedCoT-Align/experiments/main.py", line 9, in <module>
#     from data.loaders import DatasetLoader
# ModuleNotFoundError: No module named 'data'
